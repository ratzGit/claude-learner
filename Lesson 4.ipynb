# %%
#Load Headers

from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic
client = Anthropic()
model = "claude-sonnet-4-0"

# %%
# Helper functions

def add_user_message(message,text):
    user_message = {"role":"user", "content":text}
    message.append(user_message)

def add_assistant_message(message,text):
    assistant_message = {"role":"assistant", "content":text}
    message.append(assistant_message)

# %%
# Program Logic

messages = []

add_user_message(messages, "Write a 1 paragraph description of a fake database")

with client.messages.stream(
    model = model,
    max_tokens=1000,
    messages=messages,
    temperature=1.0,
) as stream:
    for text in stream.text_stream:
        print(text,end="")
        #pass

#stream.get_final_text()
# Out:
# The ChronoVault Database is a revolutionary temporal data storage system that maintains information across multiple timeline branches, allowing users to query not only current data but also potential future outcomes and historical variations. Built on quantum-encrypted nodes distributed across 47 global locations, ChronoVault employs proprietary "FluxQL" query language to navigate through its 12-dimensional data architecture, where each record exists simultaneously in past, present, and probable future states. The database automatically generates predictive data shadows based on current trends and can restore deleted information by accessing its temporal echoes from alternate timeline branches, making data loss theoretically impossible while maintaining real-time synchronization across all dimensional layers through its patented Temporal Consistency Protocol.
