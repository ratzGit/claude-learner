# %%
#Load headers

from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic
client = Anthropic()
model = "claude-sonnet-4-0"

# %%
# Helper functions

def add_user_messages(messages, text):
    user_messages = {"role":"user", "content":text}
    messages.append(user_messages)

def add_assistant_messages(messages, text):
    assistant_messages = {"role":"assistant", "content":text}
    messages.append(assistant_messages)

def chat(messages, seq=None):

   params = {
        "messages": messages,
        "max_tokens": 1000,
        "model": model,
   }

   if seq:
       params["stop_sequences"]= seq

   answer = client.messages.create(**params)
   return answer.content[0].text

# %%
# Program Logic

messages = []
seq = ["```"]

add_user_messages(messages,"Generate a very short event bridge rule as jason")
add_assistant_messages(messages,"```json")

text = chat(messages, seq)

import json

json.loads(text.strip())
# Out:
# C:\Users\rpoovadan\AppData\Local\Temp\ipykernel_63612\1450089540.py:22: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   answer = client.messages.create(**params)
# {'Name': 'ProcessOrderRule',
#  'EventPattern': {'source': ['myapp.orders'], 'detail-type': ['Order Placed']},
#  'Targets': [{'Id': '1',
#    'Arn': 'arn:aws:lambda:us-east-1:123456789012:function:ProcessOrder'}]}
