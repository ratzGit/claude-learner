# %%
import asyncio
from claude_agent_sdk import query, ClaudeAgentOptions


async def main():
    async for message in query(
        prompt="Find all TODO comments and create a summary",
        options=ClaudeAgentOptions(allowed_tools=["Read", "Glob", "Grep"]),
    ):
        if hasattr(message, "result"):
            print(message.result)


#asyncio.run(main())
await main()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\rpoovadan\Learn\Claude\.venv\Lib\site-packages\claude_agent_sdk\_internal\transport\subprocess_cli.py:474, in SubprocessCLITransport.connect(self)
#     472 stderr_dest = PIPE if self._options.stderr is not None else None
# --> 474 self._process = await anyio.open_process(
#     475     cmd,
#     476     stdin=PIPE,
#     477     stdout=PIPE,
#     478     stderr=stderr_dest,
#     479     cwd=self._cwd,
#     480     env=process_env,
#     481     user=self._options.user,
#     482 )
#     483 _ACTIVE_CHILDREN.add(self._process)
#
# File c:\Users\rpoovadan\Learn\Claude\.venv\Lib\site-packages\anyio\_core\_subprocesses.py:184, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     182     kwargs["umask"] = umask
# --> 184 return await get_async_backend().open_process(
#     185     command,
#     186     stdin=stdin,
#     187     stdout=stdout,
#     188     stderr=stderr,
#     189     cwd=cwd,
#     190     env=env,
#     191     startupinfo=startupinfo,
#     192     creationflags=creationflags,
#     193     start_new_session=start_new_session,
#     194     pass_fds=pass_fds,
#     195     **kwargs,
#     196 )
#
# File c:\Users\rpoovadan\Learn\Claude\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:2617, in AsyncIOBackend.open_process(cls, command, stdin, stdout, stderr, **kwargs)
#    2616 else:
# -> 2617     process = await asyncio.create_subprocess_exec(
#    2618         *command,
#    2619         stdin=stdin,
#    2620         stdout=stdout,
#    2621         stderr=stderr,
#    2622         **kwargs,
#    2623     )
#    2625 stdin_stream = StreamWriterWrapper(process.stdin) if process.stdin else None
#
# File C:\Python313\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File C:\Python313\Lib\asyncio\base_events.py:1802, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1801     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1802 transport = await self._make_subprocess_transport(
#    1803     protocol, popen_args, False, stdin, stdout, stderr,
#    1804     bufsize, **kwargs)
#    1805 if self._debug and debug_log is not None:
#
# File C:\Python313\Lib\asyncio\base_events.py:539, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     538 """Create subprocess transport."""
# --> 539 raise NotImplementedError
#
# NotImplementedError:
#
# The above exception was the direct cause of the following exception:
#
# CLIConnectionError                        Traceback (most recent call last)
# Cell In[3], line 15
#      11             print(message.result)
#      12
#      13
#      14 #asyncio.run(main())
# ---> 15 await main()
#
# Cell In[3], line 6, in main()
#       5 async def main():
# ----> 6     async for message in query(
#       7         prompt="Find all TODO comments and create a summary",
#       8         options=ClaudeAgentOptions(allowed_tools=["Read", "Glob", "Grep"]),
#       9     ):
#
# File c:\Users\rpoovadan\Learn\Claude\.venv\Lib\site-packages\claude_agent_sdk\query.py:123, in query(prompt, options, transport)
#     119     options = ClaudeAgentOptions()
#     121 client = InternalClient()
# --> 123 async for message in client.process_query(
#     124     prompt=prompt, options=options, transport=transport
#     125 ):
#     126     yield message
#
# File c:\Users\rpoovadan\Learn\Claude\.venv\Lib\site-packages\claude_agent_sdk\_internal\client.py:74, in InternalClient.process_query(self, prompt, options, transport)
#      72 inner = self._process_query_inner(prompt, options, transport, materialized)
#      73 try:
# ---> 74     async for msg in inner:
#      75         yield msg
#      76 finally:
#      77     # ``async for`` does NOT close its iterator when the loop body
#      78     # raises (PEP 533 was deferred). Explicitly aclose the inner
#      79     # generator first so its ``finally: await query.close()`` runs —
#      80     # i.e. the subprocess is terminated — *before* we remove the temp
#      81     # CLAUDE_CONFIG_DIR it is reading/writing.
#
# File c:\Users\rpoovadan\Learn\Claude\.venv\Lib\site-packages\claude_agent_sdk\_internal\client.py:133, in InternalClient._process_query_inner(self, prompt, options, transport, materialized)
#     127     chosen_transport = SubprocessCLITransport(
#     128         prompt=prompt,
#     129         options=configured_options,
#     130     )
#     132 # Connect transport
# --> 133 await chosen_transport.connect()
#     135 # Extract SDK MCP servers from configured options
#     136 sdk_mcp_servers = {}
#
# File c:\Users\rpoovadan\Learn\Claude\.venv\Lib\site-packages\claude_agent_sdk\_internal\transport\subprocess_cli.py:516, in SubprocessCLITransport.connect(self)
#     514 error = CLIConnectionError(f"Failed to start Claude Code: {e}")
#     515 self._exit_error = error
# --> 516 raise error from e
#
# CLIConnectionError: Failed to start Claude Code:
