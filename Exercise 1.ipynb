# %%
# Load global headers

from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic
client = Anthropic()
model = "claude-sonnet-4-0"

# %%
# Define Helper functions

def add_user_messages(messages, text):
    user_message = {"role":"user", "content":text}
    messages.append(user_message)

def add_assistant_messages(messages, text):
    assistant_message = {"role":"assistant", "content":text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model, 
        max_tokens=1000, 
        messages=messages)
    return message.content[0].text

# %%
# Make an initial list of messages
messages = []

while True:
    user_input = input("> ")
    print(">", user_input)

    add_user_messages(messages,user_input)
    answers = chat(messages)
    print("> ",answers)
    add_assistant_messages(messages,answers)
    
    print("___")
    print(answers)
    print("___")
# Out:
# > what is 400*8
# >  400 × 8 = 3,200
# ___
# 400 × 8 = 3,200
# ___
# > Divide it by 9
# >  3,200 ÷ 9 = 355.56 (rounded to two decimal places)
#
# Or as a fraction: 3,200/9 = 355 5/9
# ___
# 3,200 ÷ 9 = 355.56 (rounded to two decimal places)
#
# Or as a fraction: 3,200/9 = 355 5/9
# ___
# > select a number of your choice
# >  I'll choose 42.
#
# (It's a fun number - famously known as "the answer to the ultimate question of life, the universe, and everything" from The Hitchhiker's Guide to the Galaxy!)
# ___
# I'll choose 42.
#
# (It's a fun number - famously known as "the answer to the ultimate question of life, the universe, and everything" from The Hitchhiker's Guide to the Galaxy!)
# ___
# > Multiply it with 9
# >  42 × 9 = 378
# ___
# 42 × 9 = 378
# ___
# > Add the sum of its digits
# >  Let me find the sum of the digits of 378:
#
# 3 + 7 + 8 = 18
#
# Now adding that to 378:
#
# 378 + 18 = 396
# ___
# Let me find the sum of the digits of 378:
#
# 3 + 7 + 8 = 18
#
# Now adding that to 378:
#
# 378 + 18 = 396
# ___
